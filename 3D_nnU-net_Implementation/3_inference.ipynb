# %%
# !pip install nnunetv2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.3/206.3 kB 7.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 6.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.3/52.3 MB 21.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 56.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 49.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.1 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.listdir("/content/drive/MyDrive/BreastDM_nnUNet")
# Out:
# ['Dataset001_BreastCancer',
#  'nnUNet_preprocessed',
#  'nnUNet_results',
#  'predictions',
#  'postprocessed_predictions']

# %%
import os

folder_path = "/content/drive/MyDrive/BreastDM_nnUNet/Dataset001_BreastCancer/imagesTs"
for filename in os.listdir(folder_path):
    if filename.startswith("Copy of "):
        old_path = os.path.join(folder_path, filename)
        new_path = os.path.join(folder_path, filename.replace("Copy of ", ""))
        os.rename(old_path, new_path)

print("Renaming complete!")
# The following lines were incorrectly indented and have been removed.
# old_path = os.path.join(folder_path, filename)
# new_path = os.path.join(folder_path, filename.replace("Copy of ", ""))
# os.rename(old_path, new_path)
# Out:
# Renaming complete!

# %%
# %env nnUNet_raw=/content/drive/MyDrive/BreastDM_nnUNet
# %env nnUNet_preprocessed=/content/drive/MyDrive/BreastDM_nnUNet/nnUNet_preprocessed
# %env nnUNet_results=/content/drive/MyDrive/BreastDM_nnUNet/nnUNet_results
# Out:
# env: nnUNet_raw=/content/drive/MyDrive/BreastDM_nnUNet
# env: nnUNet_preprocessed=/content/drive/MyDrive/BreastDM_nnUNet/nnUNet_preprocessed
# env: nnUNet_results=/content/drive/MyDrive/BreastDM_nnUNet/nnUNet_results

# %%
#nnUNetv2_predict -i $nnUNet_raw/Dataset001_BreastCancer/imagesTr/BC_000_0000.nii.gz \
# !nnUNetv2_predict -i $nnUNet_raw/Dataset001_BreastCancer/imagesTs \
                 -o /content/drive/MyDrive/BreastDM_nnUNet/predictions \
                 -d Dataset001_BreastCancer \
                 -c 3d_fullres \
                 -f 0 \
                 -chk checkpoint_best.pth # Aligned with other arguments
# Out:
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# There are 44 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 44 cases that I would like to predict
#
# Predicting BC_002:
# perform_everything_on_device: True
# 100% 2/2 [00:03<00:00,  1.57s/it]
# sending off prediction to background worker for resampling and export
# done with BC_002
#
# Predicting BC_010:
# perform_everything_on_device: True
# 100% 2/2 [00:00<00:00,  4.93it/s]
# sending off prediction to background worker for resampling and export
# done with BC_010
#
# Predicting BC_024:
# ...
